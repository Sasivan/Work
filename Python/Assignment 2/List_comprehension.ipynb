# %%
#Ques 48  -

print([(x,y) for x in range(1,11) for y in range(1,11) if (x+y)%2 == 0])
# Out:
# [(1, 1), (1, 3), (1, 5), (1, 7), (1, 9), (2, 2), (2, 4), (2, 6), (2, 8), (2, 10), (3, 1), (3, 3), (3, 5), (3, 7), (3, 9), (4, 2), (4, 4), (4, 6), (4, 8), (4, 10), (5, 1), (5, 3), (5, 5), (5, 7), (5, 9), (6, 2), (6, 4), (6, 6), (6, 8), (6, 10), (7, 1), (7, 3), (7, 5), (7, 7), (7, 9), (8, 2), (8, 4), (8, 6), (8, 8), (8, 10), (9, 1), (9, 3), (9, 5), (9, 7), (9, 9), (10, 2), (10, 4), (10, 6), (10, 8), (10, 10)]

# %%
#Ques 49 -

files = ['report.pdf', 'data.csv', 'image.png', 'notes.txt', 'summary.pdf', 'photo.jpg']
print(list(x.split('.')[0] for x in files))
# Out:
# ['report', 'data', 'image', 'notes', 'summary', 'photo']

# %%
#Ques 50 -

matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]
t = [[r[i] for r in matrix] for i in range(len(matrix[0]))]
print("Transpose :" ,t,"| Matrix",matrix)
# Out:
# Transpose : [[1, 4, 7], [2, 5, 8], [3, 6, 9]] | Matrix [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
